# %%
from langchain.llms import OpenAI

# %%
import os 
os.environ["PEN_API_KEY"]=''

# %%
llm = OpenAI(openai_api_key = os.environ["OPEN_API_KEY"],temperature = 0.6)

# %%
Text ='What is the capital of India'
print(llm.predict(Text))
# Out:
# The capital of India is New Delhi.

# %%
llm.predict("can you write a poem about AI")
# Out:
# '\n\nArtificial intelligence, a marvel of technology\nCreated by humans, with endless possibility\nA digital mind, with endless capacity\nTo learn, to adapt, and to think with clarity\n\nA world of data, at its fingertips\nAble to process, and analyze in blips\nFrom simple tasks, to complex equations\nAI has surpassed human limitations\n\nWith algorithms and codes, it can make decisions\nPredicting the future, with startling precision\nBut can it truly feel, or understand emotion\nOr is it just a machine, without any notion\n\nSome fear its power, and what it may become\nWill it take over, and leave us feeling numb\nBut others see potential, in its endless use\nTo improve our lives, with its intelligence fuse\n\nFrom self-driving cars, to virtual assistants\nAI has become, an integral existence\nIt helps us connect, and navigate our world\nBut can it replace, the human soul unfurled\n\nFor no matter how advanced, AI may be\nIt lacks the essence, of humanity\nThe ability to love, to feel and to dream\nIs what truly sets us, apart from machines\n\nSo let us embrace, the wonders of AI\nBut never forget, the beauty of the human eye\nFor we are'

# %%
### HUGGINGFACE

# %%
os.environ["HUGGINGFACEHUB_API_TOKEN"]=""

# %%
from langchain import HuggingFaceHub
llm_huggingface = HuggingFaceHub(repo_id="google/flan-t5-large",model_kwargs ={"temperature":0,"max_length":64})

# %%
output = llm_huggingface.predict("can you tell me the capital of russia")
print(output)
# Out:
# Moscow

# %% [markdown]
# PROMPT TEMPLATES AND LLMCHAIN

# %%
from langchain.prompts import PromptTemplate

# %%
prompt_template=PromptTemplate(input_variables=['country'],
template="Tell me the capital of this {country}")

# %%
prompt_template.format(country ="India")
# Out:
# 'Tell me the capital of this India'

# %%
from langchain.chains import LLMChain

chain = LLMChain(llm=llm, prompt=prompt_template)
print(chain.run("India"))
# Out:
# d:\ANACONDA\Lib\site-packages\langchain_core\_api\deprecation.py:119: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# The capital of India is New Delhi.

# %% [markdown]
# COMBINING MULTIPLE CHAINS USING SIMPLE SEQUENTIAL CHAIN

# %%
Capital_template=PromptTemplate(input_variables=['country'],
template="Tell me the capital of this {country}")

capital_chain = LLMChain(llm=llm,prompt= Capital_template)

famous_template=PromptTemplate(input_variables=['Capital'],
template="Suggest me some amazing places to visit in{Capital}")

# %%
famous_chain = LLMChain(llm=llm,prompt=famous_template)

# %%
from langchain.chains import SimpleSequentialChain
chain = SimpleSequentialChain(chains =[capital_chain,famous_chain])
chain.run("India")
# Out:
# " Here are some amazing places to visit in New Delhi:\n\n1. Red Fort: This iconic monument is a must-visit for its beautiful architecture and historical significance.\n\n2. India Gate: This war memorial is a popular spot for picnics and evening strolls.\n\n3. Qutub Minar: This UNESCO World Heritage Site is the tallest brick minaret in the world and a stunning example of Indo-Islamic architecture.\n\n4. Humayun's Tomb: Another UNESCO World Heritage Site, this tomb is a beautiful blend of Persian and Indian architecture.\n\n5. Lotus Temple: This stunning temple is shaped like a lotus flower and is a symbol of unity and peace.\n\n6. Rashtrapati Bhavan: The official residence of the President of India, this grand building is a must-visit for its beautiful architecture and gardens.\n\n7. Akshardham Temple: This massive temple complex is a popular tourist attraction for its stunning architecture, exhibitions, and light and sound show.\n\n8. Chandni Chowk: This bustling market in Old Delhi is a must-visit for its vibrant atmosphere, street food, and shopping.\n\n9. National Gallery of Modern Art: Art lovers will enjoy exploring this museum, which houses a collection of modern and contemporary Indian art.\n\n10. H"

# %% [markdown]
# SEQUENTIAL CHAIN

# %%
# Prompt 1
capital_template = PromptTemplate(
    input_variables=['country'],
    template="Tell me the capital of {country}"
)
capital_chain = LLMChain(llm=llm, prompt=capital_template, output_key='capital')

# Prompt 2
famous_template = PromptTemplate(
    input_variables=['capital'],  # ✅ lowercase here!
    template="Suggest me some amazing places to visit in {capital}"
)
famous_chain = LLMChain(llm=llm, prompt=famous_template, output_key='places')

# %%
# Sequential Chain
from langchain.chains import SequentialChain

chain = SequentialChain(
    chains=[capital_chain, famous_chain],
    input_variables=['country'],
    output_variables=['capital', 'places'],
    verbose=True
)

# Run it
result = chain({'country': 'India'})
print(result)
# Out:
# d:\ANACONDA\Lib\site-packages\langchain_core\_api\deprecation.py:119: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# > Entering new SequentialChain chain...
#
# > Finished chain.
# {'country': 'India', 'capital': '\n\nThe capital of India is New Delhi.', 'places': " Here are some amazing places to visit in Delhi:\n\n1. Red Fort - This iconic monument is a must-visit for its beautiful architecture and rich history.\n\n2. Qutub Minar - The tallest minaret in India, Qutub Minar is a UNESCO World Heritage Site and a popular tourist attraction.\n\n3. India Gate - This war memorial is a symbol of national pride and a popular picnic spot.\n\n4. Humayun's Tomb - Another UNESCO World Heritage Site, this monument is known for its stunning Mughal architecture.\n\n5. Lotus Temple - This beautiful temple is shaped like a lotus flower and is open to people of all religions.\n\n6. Akshardham Temple - One of the largest Hindu temples in the world, Akshardham is known for its intricate carvings and beautiful gardens.\n\n7. Chandni Chowk - This bustling market in Old Delhi is a paradise for foodies and shoppers.\n\n8. Jama Masjid - The largest mosque in India, Jama Masjid is a beautiful blend of Mughal and Persian architecture.\n\n9. National Gallery of Modern Art - Art lovers must visit this gallery to admire a vast collection of modern and contemporary Indian art.\n\n10. Hauz Khas Village - A trendy neighborhood known for"}

# %% [markdown]
# CHATMODELS WITH CHATOPENAI

# %%
from langchain.chat_models import ChatOpenAI
from langchain.schema import HumanMessage,SystemMessage,AIMessage

# %%
chatllm=ChatOpenAI(openai_api_key=os.environ["OPEN_API_KEY"],temperature=0.6,model='gpt-3.5-turbo')
# Out:
# d:\ANACONDA\Lib\site-packages\langchain_core\_api\deprecation.py:119: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(

# %%
chatllm([
SystemMessage(content="Yor are a comedian AI assitant"),
HumanMessage(content="Please provide some comedy punchlines on AI")
])
# Out:
# d:\ANACONDA\Lib\site-packages\langchain_core\_api\deprecation.py:119: LangChainDeprecationWarning: The method `BaseChatModel.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# AIMessage(content='1. "Why did the AI break up with the chatbot? It couldn\'t handle its algorithms anymore!"\n2. "I asked my AI assistant to tell me a joke, and it replied, \'I can\'t, I\'m too busy processing your embarrassing search history!\'"\n3. "Why did the AI go to therapy? It had too many unresolved bugs in its code!"\n4. "I tried teaching my AI to do stand-up comedy, but all it came up with were dad jokes... I guess it\'s stuck in \'dad mode\'!"\n5. "I told my AI to make me laugh, and it responded, \'I\'m sorry, Dave, I\'m afraid I can\'t do that... but I can search for jokes on the internet for you!\'"', response_metadata={'token_usage': {'completion_tokens': 158, 'prompt_tokens': 27, 'total_tokens': 185, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-ca93d3a6-8b78-490f-ad28-b15ed36915c5-0')

# %% [markdown]
# Prompt Template + LLM +Output Parsers

# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts.chat import ChatPromptTemplate
from langchain.schema import BaseOutputParser

# %%
class Commaseperatedoutput(BaseOutputParser):
    def parse(self,text:str):
        return text.strip().split(",")

# %%
template="Your are a helpful assistant. When the use given any input , you should generate 5 words synonyms in a comma seperated list"
human_template="{text}"
chatprompt=ChatPromptTemplate.from_messages([
    ("system",template),
    ("human",human_template)


])

# %%
chain=chatprompt|chatllm|Commaseperatedoutput()

# %%
chain.invoke({"text":"intelligent"})
# Out:
# ['smart', ' clever', ' bright', ' knowledgeable', ' astute']
